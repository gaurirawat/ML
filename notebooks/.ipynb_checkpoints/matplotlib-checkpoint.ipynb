# %%
# import matplotlib.pyplot as plt
import matplotlib
print(matplotlib.is_interactive())
import matplotlib.pyplot as plt

plt.ion()
print(matplotlib.is_interactive())
#Rseult is true. Hence the plots are automatically showing up on the screen without having to call show()
# Out:
# True
# True

# %%
plt.plot([2,4,6,8], [5,10,15,20])

# %%
plt.plot([2,4,6,8], [5,10,15,20], color = 'red')

# %%
plt.plot([2,4,6,8,10,12], [5,15,10,12,18,8])
plt.xlabel('age', fontsize = 15, color = 'red')
plt.ylabel('height', fontsize = 15, color = 'green')

# used to view only a portion of the actual graph 
plt.xlim(4,10)
# Out:
# (4.0, 10.0)
